# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarshinivarma05/rare-skin-classifier/blob/harsha-training-improvements/harsha_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ipynb
